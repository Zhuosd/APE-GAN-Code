# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/MyDrive/AEGAN/AE_GAN_IAENG')
# !nvidia-smi
# !ls

# %%
# %%shell
# for ((i=1; i<=300; i++))
# do
#   echo ${i}
#   python test_model_cifar.py --eps 0.03 --gan_path ./checkpoint/cifar/${i}.tar
# done
# Out:
# 1
# Accuracy: normal 83.980003, fgsm 1.000000, ape 40.490002
# 2
# Accuracy: normal 83.980003, fgsm 1.000000, ape 50.209999
# 3
# Accuracy: normal 83.980003, fgsm 1.000000, ape 60.060001
# 4
# Accuracy: normal 83.980003, fgsm 1.000000, ape 65.309998
# 5
# Accuracy: normal 83.980003, fgsm 1.000000, ape 66.869995
# 6
# Accuracy: normal 83.980003, fgsm 1.000000, ape 67.869995
# 7
# Accuracy: normal 83.980003, fgsm 1.000000, ape 68.879997
# 8
# Accuracy: normal 83.980003, fgsm 1.000000, ape 69.489998
# 9
# Accuracy: normal 83.980003, fgsm 1.000000, ape 70.290001
# 10
# Accuracy: normal 83.980003, fgsm 1.000000, ape 70.380005
# 11
# Accuracy: normal 83.980003, fgsm 1.000000, ape 70.090004
# 12
# Accuracy: normal 83.980003, fgsm 1.000000, ape 72.070000
# 13
# Accuracy: normal 83.980003, fgsm 1.000000, ape 70.920006
# 14
# Accuracy: normal 83.980003, fgsm 1.000000, ape 72.239998
# 15
# Accuracy: normal 83.980003, fgsm 1.000000, ape 72.169998
# 16
# ...

# %%
252,246,244,239,235,229,223,205,197,188,186,185,183,179,172-176,169,166,164,158-162,152-156,148,149,
143,144,138,134,133,131,130,128,126,120-122,115-117,112,113,109,100-107,98,96,93,87,83,81,80,74,75
67,65,57,52,53,48,46,38,39,35,
