# %%
from google.colab import drive
drive.mount('/content/gdrive')
import os
os.chdir('./gdrive/MyDrive/AEGAN/AE_GAN_IAENG')
# !nvidia-smi
# !ls

# %%
# %%shell
# for ((i=1; i<=300; i++))
# do
#   echo ${i}
#   python test_model_mnist.py --eps 0.5 --gan_path ./checkpoint/mnist/${i}.tar
# done
# Out:
# 1
# Accuracy: normal 98.379997, fgsm 2.500000, ape 93.279999
# 2
# Accuracy: normal 98.659996, fgsm 2.320000, ape 95.320000
# 3
# Accuracy: normal 98.470001, fgsm 2.510000, ape 95.389999
# 4
# Accuracy: normal 98.500000, fgsm 2.510000, ape 96.650002
# 5
# Accuracy: normal 98.419998, fgsm 2.460000, ape 87.309998
# 6
# Accuracy: normal 98.459999, fgsm 2.470000, ape 79.549995
# 7
# Accuracy: normal 98.500000, fgsm 2.620000, ape 77.050003
# 8
# Accuracy: normal 98.369995, fgsm 2.410000, ape 76.010002
# 9
# Accuracy: normal 98.500000, fgsm 2.580000, ape 82.120003
# 10
# Accuracy: normal 98.500000, fgsm 2.600000, ape 81.209999
# 11
# Accuracy: normal 98.589996, fgsm 2.500000, ape 78.969994
# 12
# Accuracy: normal 98.500000, fgsm 2.450000, ape 75.010002
# 13
# Accuracy: normal 98.669998, fgsm 2.610000, ape 73.820000
# 14
# Accuracy: normal 98.529999, fgsm 2.660000, ape 72.439995
# 15
# Accuracy: normal 98.439995, fgsm 2.660000, ape 69.669998
# 16
# ...

# %%
>20

# %%
300,295,296,286,287,283,277,274,268,269,266,259,256,254,243,239,226,222,216,
